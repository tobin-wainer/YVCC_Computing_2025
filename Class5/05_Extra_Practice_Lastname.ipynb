# %% [markdown]
# ## Extra Practice with Logic Statements and for loops

# %% [markdown]
# In class on Wednesday we got some requests for some extra practice! Ask and you shall receive!

# %% [markdown]
# ### Example 6 (last one from the notebook in classs)
#
# In the cell below, create an empty list called `actual_prices`, then using a `for` loop, append to it the actual price that you'll pay for each grocery. I.e., turn the too-long code in the cell above into some nice efficient code using a `for` loop.

# %%
actual_prices = []

# Write your for loop!

print(actual_prices)

# %% [markdown]
# ## Combining control flow statements
#
# Now let's put everything together!
#
# ### EP1
#
# Do what you did in example 6, but only print the grocery and its corresponding price from the `actual_prices` list if the grocery's actual price is less than $1.50

# %% [markdown]
# ### EP2
#
# Now, do you what you did in example 6, but only print the grocery and its corresponding price from the `actual_prices` list if the grocery's actual price is less than $1.50 `or` if that grocery's name is "candy"

# %% [markdown]
# # ```numpy``` practice

# %% [markdown]
# ### 1. Run the cell below to import ```numpy```.

# %%
import numpy as np

# %% [markdown]
# ### 2. Choose a value and set the variable ```x``` to that value.

# %% [markdown]
# ### 3. What is the command to compute the square of x? Its cube?  Compute and print both values in the cell below.

# %% [markdown]
# ### 4. Choose an angle ϴ, and set the variable ```theta``` to its value (a number)

# %% [markdown]
# ### 5. What is sin(ϴ)? cos(ϴ)? Angles can be measured in degrees and radians. Which of these is used by the ```np.sin``` and ```np.cos``` functions? (Hint: you can convert an angle from degrees to radians by multiplying it by ```np.pi/180```)

# %% [markdown]
# ### 6. Look up what the function ```np.linspace``` does by bringing up the help window in your Jupyter notebook (check back to the ```numpy``` lesson notebok if you don't remember how to do this). Use ```np.linspace``` to create an array called ```points``` that contains 500 values evenly spaced  between -1 and 1.

# %% [markdown]
# ### 7. What expression will print the 53rd element of ```points```? What is the value of the 53rd element?

# %% [markdown]
# ### 8. Make a new array that includes only the positive values in ```points``` called ```positive_points```. Make another array of the sinusoid with this new ```positive_points``` array using the same command as above, but replacing ```points``` with ```positive_points``` each time it appears.

# %% [markdown]
# ### 9. Make another array called ```new_points``` that contains values from 0 to 500 evenly spaced by 1. Then make an array ```even_points``` that contains only the values from ```new points``` with even indeces. Make another plot of the sinusoid using the ```even_points``` array. Does it look different?

# %% [markdown]
# ## Combining ```numpy``` and ```for``` loops

# %% [markdown]
# ### EP3
#
# Now create an empty list named ```even_points```, and write a ```for``` loop which will loop thorough the values of your ```new_points``` array, and only append values to list that are even

# %%
new_points = []

# For loop

# %% [markdown]
# ### EP4
#
# In this example, we'll create an infinite loop that doesn't go on forever, because it terminates with a `break` statement. `break` forces python to end a loop.
#
# Let's start a `counter` at 10, and iteratively subtract one from `counter`. We could make the `while` loop terminate when `counter == 1` by writing the loop like this
# ```python
# counter = 10
#
# while counter > 1:
#     counter -=1
#
# print(counter)
# ```
# Or, we could `break` out of an infinite loop:
# ```python
# counter = 10
#
# # This loop is infinite on purpose:
# while True:
#     counter -= 1
#
#     # When counter is equal to one, break out of the loop:
#     if counter == 1:
#         break
#
# print(counter)
# ```
#
# ### EP5
#
# 1. Copy and paste the loop with the `break` from above into the cell below, and check that it works.
#
# 2. Modify the loop so that it terminates when the `counter` is at negative one million (reminder: you can use `e` for scientific notation)
#
# 3. Now modify the loop so that it counts down from 10 to negative one million by twos.
